# %%
#題目: 將某篇文章以上下文相同，比方三連詞(trigram)方式修改內容
#說明：某篇文章中我們可以找出所有的三連詞(trigram)，以及在前字與後字出現時，
#按照出現度隨機選出一個字去換掉中間字，這是利用三連詞修改文章內容的最基本作法。
#一旦字典的資料結構建立，我們就以某種機率(比方20%)去置換原文，並將置換文與原文印出來

#延伸: 可用五連詞或七連詞去取代中間字，可利用三連詞之前兩字去更換第三字，
#可增加加詞性的相同性(Parts Of Sentence)提高可讀性，甚至使用 Word2Vec, Glove，或者RNN的

#範例程式檔名: article_modifier_自動文件修改器.py。
#模組: sklearn, random, numpy, nltk, bs4
#輸入檔：./electronics/positive.review
#成績：被置換文的合理性與可讀性

# 使用三連詞 trigrams 練習簡易文件產生器
from __future__ import print_function, division
from future.utils import iteritems
from builtins import range

import nltk
import random
import numpy as np

from bs4 import BeautifulSoup

# %%
# load the reviews
positive_reviews = BeautifulSoup(open('positive.review', encoding='ISO-8859-1').read(), "lxml")
positive_reviews = positive_reviews.findAll('review_text')

# %%
# 提出 五連詞 並置入字典
# (w1, w3) 當作 key, [ w2 ] 當作值
fivegrams = {}
for review in positive_reviews:
    s = review.text.lower()
    tokens = nltk.tokenize.word_tokenize(s)
    for i in range(len(tokens) - 4):
        k = (tokens[i], tokens[i+4])
        #print(f'{tokens[i], tokens[i+1], tokens[i+2], tokens[i+3], tokens[i+4]}')
        if k not in fivegrams:
            fivegrams[k] = []
        fivegrams[k].append(tokens[i+2])

# %%
fivegrams
# Out:
# {('i', 'due'): ['this', 'corded'],
#  ('purchased', 'to'): ['unit', 'was', 'unfortunately', 'cable'],
#  ('this', 'frequent'): ['due'],
#  ('unit', 'blackouts'): ['to'],
#  ('due', 'in'): ['frequent', 'v7', 'the'],
#  ('to', 'my'): ['blackouts',
#   'one',
#   'one',
#   'back',
#   'well',
#   'good',
#   ',',
#   'stuff',
#   'even',
#   'it',
#   '.',
#   'unit',
#   'now-a-days',
#   'parts',
#   'some',
#   'interference',
#   'it',
#   'sure',
#   'and',
#   'all',
#   'photos',
#   '.',
#   'message',
#   'one',
#   'them',
#   'audio',
#   'them',
#   'players',
#   'around',
#   'better',
#   'them',
#   '8x10s',
#   'meeting',
#   'audio',
#   'data',
#   'room',
#   'connected'],
#  ('frequent', 'area'): ['in'],
#  ('blackouts', 'and'): ['my'],
#  ('in', '2'): ['area', 'for', '=', 'department'],
#  ('my', 'power'): ['and'],
#  ('area', 'supplies'): ['2'],
#  ('and', 'going'): ['power'],
#  ('2', 'bad'): ['supplies'],
#  ('power', '.'): ['going', 'is'],
#  ('supplies', 'it'): ['bad'],
#  ('going', 'will'): ['.'],
#  ('bad', 'run'): ['it'],
#  ('.', 'my'): ['will',
#   'case',
#   'primarily',
#   'have',
#   'i',
#   'happy',
#   'i',
#   'began',
#   'recently',
#   "'ve",
#   'great',
#   'i',
#   'have',
#   'price',
#   ',',
#   'i',
#   'i',
#   'exceeded',
#   'exceeded',
#   'plugged',
#   'probably',
#   'still',
#   'beautifully',
#   'i',
#   ',',
#   'here',
#   'put',
#   'may',
#   'me',
#   'was',
#   'went',
#   'look',
#   'ipod',
#   'put',
#   'i'],
#  ('it', 'cable'): ['run', 'a'],
#  ('will', 'modem'): ['my'],
#  ('run', ','): ['cable', 'or', 'completely'],
#  ('my', 'router'): ['modem'],
#  ('cable', ','): [',', 'great', 'at', 'ofc', 'its'],
#  ('modem', 'pc'): ['router'],
#  (',', ','): [',',
#   'the',
#   'is',
#   'the',
#   ',',
#   'f/4l',
#   '?',
#   'hard',
#   'very',
#   ',',
#   ',',
#   'aggresive',
#   'hq',
#   'a',
#   'on',
#   'the',
#   'the',
#   'high',
#   'connected',
#   'rear',
#   'optical',
#   'might',
#   '1100mah',
#   ',',
#   'not',
#   'the',
#   'battery',
#   'out',
#   'tad',
#   'sound',
#   'lansing',
#   'even',
#   ',',
#   ',',
#   ',',
#   'dvd',
#   ',',
#   'but',
#   'became',
#   'with',
#   '1',
#   'my',
#   'subwoofer',
#   ',',
#   'not',
#   ',',
#   'al',
#   ',',
#   'the',
#   ',',
#   ',',
#   ',',
#   'very',
#   ',',
#   ',',
#   'other',
#   'or',
#   ',',
#   'low',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   'sound',
#   'earwax',
#   'of',
#   'ring',
#   'caller',
#   'the',
#   'my',
#   'great',
#   'my',
#   'less',
#   'many',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   'media',
#   'fits',
#   ',',
#   'all',
#   'way',
#   'you',
#   'and',
#   ',',
#   'or',
#   '&',
#   '.',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   '300+',
#   'the',
#   'to',
#   'loads',
#   'my',
#   'plugged',
#   'course',
#   '.',
#   ',',
#   'lake',
#   ',',
#   '1.8',
#   '14.1',
#   'plane',
#   'after',
#   'is',
#   'movie',
#   "'s",
#   'vegas',
#   'were',
#   'of',
#   'camping',
#   '2',
#   '4',
#   'juli',
#   'for',
#   'sennheiser',
#   'the',
#   "'m",
#   'not',
#   'reasonably',
#   'the',
#   'and',
#   'too',
#   'keyboard',
#   'apple',
#   'paging',
#   'card',
#   'built-in',
#   'for',
#   'soon',
#   'studio',
#   'preparing',
#   'used',
#   'worn',
#   'loudly',
#   'know',
#   'memory',
#   ',',
#   'more',
#   ',',
#   'stated',
#   'all',
#   'a',
#   ',',
#   'crank',
#   'a',
#   ',',
#   'noaa',
#   'storage',
#   'it',
#   'to',
#   'to',
#   ',',
#   ',',
#   ',',
#   ',',
#   'memory',
#   'even',
#   'view',
#   '?',
#   'to',
#   'that',
#   'fits',
#   'prints',
#   'stick'],
#  ('router', 'and'): ['pc', 'ap'],
#  (',', 'lcd'): [','],
#  ('pc', 'monitor'): ['and'],
#  (',', 'for'): ['lcd',
#   'it',
#   'will',
#   'used',
#   "n't",
#   'is',
#   'the',
#   'can',
#   'when',
#   'phone',
#   'default',
#   'notice',
#   ',',
#   'has',
#   "'m",
#   "'s",
#   'works',
#   'it',
#   'would',
#   "'s",
#   'programmed',
#   'blame',
#   'was',
#   'is',
#   'thank',
#   'not',
#   'each',
#   'you'],
#  ('and', '5'): ['monitor', 'data'],
#  ('lcd', 'minutes'): ['for'],
#  ('monitor', '.'): ['5', 'are', 'too'],
#  ('for', 'this'): ['minutes',
#   'replacement',
#   'price',
#   'feedback',
#   'better',
#   'users',
#   'money',
#   'money',
#   'scrolling',
#   'ipods',
#   'when',
#   'price'],
#  ('5', 'is'): ['.', 'from'],
#  ('minutes', 'more'): ['this'],
#  ('.', 'than'): ['is',
#   'faster',
#   "'s",
#   'for',
#   'more',
#   'more',
#   'are',
#   'is',
#   'is',
#   'own',
#   'capacity'],
#  ('this', 'enough'): ['more'],
#  ('is', 'time'): ['than', 'at', 'there'],
#  ('more', 'to'): ['enough', 'and', 'sustain', 'and', 'enough', 'less', ','],
#  ('than', 'save'): ['time'],
#  ('enough', 'work'): ['to'],
#  ('time', 'and'): ['save', 'all', 'good', 'do'],
#  ('to', 'shut'): ['work'],
#  ('save', 'down'): ['and'],
#  ('work', '.'): ['shut',
#   'the',
#   'all',
#   'un-seen',
#   'the',
#   'that',
#   'with',
#   'the',
#   'other'],
#  ('and', 'equally'): ['down'],
#  ('shut', 'important'): ['.'],
#  ('down', ','): ['equally', 'whatever', 'more', 'night', 'the'],
#  ('.', 'i'): ['important',
#   'really',
#   'beware',
#   'expect',
#   'only',
#   'the',
#   'only',
#   'again',
#   'only',
#   'jpeg',
#   'noticed',
#   'first',
#   'fact',
#   'know',
#   "'m",
#   "'m",
#   'disclaimer',
#   'fact',
#   'love',
#   'right',
#   'fact',
#   'first',
#   'only',
#   'fact',
#   'all',
#   'means',
#   "'s",
#   'far',
#   'recommended',
#   ',',
#   'company',
#   'note',
#   'though',
#   'only',
#   'told',
#   "'s",
#   'second',
#   'start',
#   '.',
#   'only',
#   'only',
#   'first',
#   'problems',
#   ',',
#   'felt',
#   'am',
#   "'m",
#   'much',
#   'like',
#   'way',
#   'also',
#   'only',
#   ',',
#   'panasonic',
#   'far',
#   'canon',
#   ',',
#   'also',
#   'makes',
#   'concerned',
#   'example',
#   'this',
#   'now',
#   "'m",
#   'only',
#   'being',
#   'in',
#   'way',
#   'thing',
#   'shirts',
#   'only',
#   'again',
#   'weeks',
#   'to',
#   'only',
#   'home',
#   'best',
#   'supported',
#   'to',
#   'all',
#   'feature',
#   'am',
#   'far',
#   'fact',
#   'only',
#   'is',
#   'other',
#   'ordered',
#   'the',
#   'only',
#   'is',
#   'far',
#   's-video',
#   'first',
#   ',',
#   'only',
#   'only',
#   'lenmar',
#   "'m",
#   'few',
#   'only',
#   ':',
#   "'m",
#   'only',
#   'this',
#   'big',
#   'home',
#   'a',
#   'first',
#   'waiting',
#   'design',
#   'that',
#   "'s",
#   'that',
#   'only',
#   'also',
#   'biggest',
#   'really',
#   'never',
#   'only',
#   'than',
#   'is',
#   'best',
#   'other',
#   'only',
#   'that'],
#  ('equally', 'know'): [','],
#  ('important', 'that'): ['i', 'tv'],
#  (',', 'my'): ['know',
#   '2',
#   'i',
#   ',',
#   'works',
#   ',',
#   'slinglink',
#   'bombed',
#   'to',
#   'up',
#   'system',
#   'it',
#   'least',
#   'can',
#   'also',
#   'so',
#   'it',
#   "'ve",
#   'quality',
#   'limited',
#   'prints'],
#  ('i', 'electronics'): ['that'],
#  ('know', 'are'): ['my', 'aa'],
#  ('that', 'receiving'): ['electronics'],
#  ('my', 'clean'): ['are'],
#  ('electronics', 'power'): ['receiving'],
#  ('are', '.'): ['clean',
#   'very',
#   'to',
#   'to',
#   'than',
#   'and',
#   'shiny',
#   'same',
#   '!',
#   'great',
#   'bit',
#   'by',
#   'and',
#   'same',
#   '!',
#   'the',
#   'and',
#   'high',
#   'near',
#   'that',
#   'around',
#   'to',
#   'great',
#   'and',
#   'or',
#   'the',
#   'brilliantly',
#   'to',
#   'and'],
#  ('receiving', 'i'): ['power', 'tunejuice'],
#  ('clean', 'feel'): ['.'],
#  ('power', 'that'): ['i'],
#  ('.', 'this'): ['feel',
#   'i',
#   'canon',
#   'manufacturers',
#   'highly',
#   'have',
#   'would',
#   'someone',
#   'size',
#   'have',
#   'actually',
#   'can',
#   'off',
#   'in',
#   'highly',
#   'features',
#   ',',
#   'though',
#   "n't",
#   'will',
#   'mainly',
#   'highly',
#   'canon',
#   'highly',
#   'really',
#   'highly',
#   'sound',
#   ',',
#   'my',
#   'recording',
#   'definitely',
#   'really',
#   "n't",
#   'truly',
#   'stereo',
#   'highly',
#   'never',
#   'would',
#   'would',
#   'strongly',
#   'can',
#   'strongly',
#   'i',
#   'summary',
#   'would',
#   'have',
#   ',',
#   'this',
#   'would',
#   'because',
#   'am',
#   'would',
#   'openness',
#   'will',
#   'would',
#   'would',
#   'far',
#   'wife',
#   'more',
#   'highly',
#   'i',
#   "'ve",
#   'just',
#   'you',
#   'the',
#   'have',
#   'in',
#   'strap',
#   'now',
#   'say',
#   'anyone',
#   'nano',
#   'am',
#   'wonder',
#   'had',
#   'can',
#   'up',
#   'your',
#   'really'],
#  ('i', 'investment'): ['that'],
#  ('feel', 'is'): ['this', 'low-end'],
#  ('that', 'minor'): ['investment'],
#  ('this', 'compared'): ['is'],
#  ('investment', 'to'): ['minor'],
#  ('is', 'the'): ['compared',
#   'best',
#   'make',
#   'in',
#   '.',
#   'gets',
#   'flat',
#   'unwatchable',
#   'good',
#   'good',
#   'endorsed',
#   'cheaper',
#   'handy',
#   'to',
#   'clear',
#   'cool',
#   'stylish',
#   ',',
#   'bright',
#   'favorite',
#   'gone',
#   'cooler',
#   ',',
#   'nice',
#   'superior',
#   'being',
#   'differentiating',
#   ':',
#   'one',
#   'good',
#   'quality',
#   'little',
#   'fact',
#   'audible',
#   'comfortable',
#   'quantity/extent',
#   'understandable',
#   'helpful',
#   'suited',
#   'good',
#   'as',
#   'the',
#   'in',
#   'flawless',
#   'down',
#   'range',
#   'hint',
#   'stamp',
#   'breeze',
#   'pain',
#   'bad',
#   'expensive',
#   'running',
#   'buttons',
#   ',',
#   'mentioned',
#   'expensive',
#   'speedy',
#   '(',
#   'successor',
#   'little',
#   'and',
#   'reasonable',
#   'little',
#   'it',
#   'purple',
#   'back',
#   'good',
#   'better',
#   'excerpt',
#   'used',
#   'awesome',
#   'good',
#   'great',
#   'i',
#   'connections',
#   'it',
#   '.',
#   'better',
#   'better',
#   'it',
#   'good',
#   'review',
#   'focus',
#   'better'],
#  ('minor', 'loss'): ['to'],
#  ('compared', 'of'): ['the'],
#  ('to', 'valuable'): ['loss'],
#  ('the', 'data'): ['of'],
#  ('loss', 'or'): ['valuable'],
#  ('of', 'the'): ['data',
#   'newness',
#   'box',
#   'receiver',
#   'pick',
#   ',',
#   'wires',
#   'and',
#   'cable',
#   'left',
#   '.',
#   'things',
#   'negativity',
#   'the',
#   'back',
#   'bass',
#   'to',
#   'e20s',
#   'space',
#   'product',
#   'sound',
#   '(',
#   'selection',
#   'and',
#   'review',
#   '.',
#   'earpiece',
#   'to',
#   'nano',
#   'may',
#   'price',
#   'way',
#   'features',
#   'effectively',
#   'units',
#   'positions',
#   'controls',
#   'pack',
#   'music',
#   ',',
#   'memory',
#   'hd-420s',
#   'volume',
#   'type',
#   'to',
#   'ink',
#   'product',
#   'headphones',
#   'screens',
#   'phone',
#   'that',
#   'product',
#   'size',
#   'wireless',
#   'printer',
#   'hour',
#   '.',
#   ',',
#   'them',
#   'reception',
#   'guitar',
#   'keys'],
#  ('valuable', 'failure'): ['or'],
#  ('data', 'of'): ['the'],
#  ('or', 'equipment'): ['failure'],
#  ('the', 'due'): ['of', 'protection'],
#  ('failure', 'to'): ['equipment'],
#  ('of', 'a'): ['due',
#   'me',
#   'recorders',
#   'stars',
#   '.',
#   'discs',
#   'displays',
#   'airplane',
#   'pinna',
#   'for',
#   'player',
#   'only',
#   ',',
#   'heaphone',
#   'and',
#   'fits',
#   'machine',
#   'batteries',
#   'staring',
#   ',',
#   'band',
#   'seat',
#   'or',
#   'accommodate',
#   'even',
#   'can',
#   'safely',
#   ',',
#   ')',
#   '.',
#   'can'],
#  ('equipment', 'power'): ['to', 'protected'],
#  ('due', 'spike'): ['a'],
#  ('to', 'or'): ['power',
#   'cds',
#   'about',
#   'the',
#   'the',
#   'into',
#   'it',
#   'external',
#   'your',
#   'audio',
#   'home',
#   'something',
#   'an',
#   'unshielded',
#   'arrow',
#   'refilled'],
#  ('a', 'an'): ['spike',
#   'input',
#   'junkie',
#   'system',
#   'signal',
#   'cable',
#   'annoyance',
#   'signal',
#   'cable',
#   'next'],
#  ('power', 'irregular'): ['or'],
#  ('spike', 'power'): ['an'],
#  ('or', 'supply'): ['irregular'],
#  ('an', '.'): ['power',
#   'digital',
#   'pen',
#   'low',
#   'k8v-x',
#   'digital',
#   'also',
#   'power',
#   'button',
#   'drone',
#   'for',
#   'at',
#   'wireless',
#   'file',
#   'purchase',
#   'canon',
#   'listening',
#   'nor',
#   'route',
#   'spam'],
#  ('irregular', 'as'): ['supply'],
#  ('power', 'always'): ['.'],
#  ('supply', ','): ['as'],
#  ('.', 'amazon'): ['always', 'usa', 'switching', '29.95', 'service', 'a'],
#  ('as', 'had'): [','],
#  ('always', 'it'): ['amazon', 'on', 'up'],
#  (',', 'to'): ['had',
#   'i',
#   'is',
#   'fitting',
#   'it',
#   'i',
#   "'s",
#   'text',
#   'am',
#   'are',
#   'has',
#   'someone',
#   'durable',
#   'might',
#   'once',
#   "'ve",
#   'your',
#   'speaks',
#   "n't",
#   "'d",
#   'are',
#   'also',
#   'i',
#   "n't",
#   'may',
#   "'s",
#   'still',
#   'pictures',
#   'the',
#   "'d",
#   'information',
#   'just',
#   'am',
#   'were',
#   'my',
#   'have',
#   'i',
#   'one',
#   'i',
#   'buttons',
#   'brings',
#   'will',
#   'are',
#   'superior',
#   'enough',
#   'my',
#   'i',
#   'would',
#   'am',
#   'would',
#   'you',
#   'continually',
#   "'s",
#   'you',
#   'was',
#   'do',
#   'stereo',
#   'stereo',
#   'was',
#   'getting',
#   'form-factor',
#   'you',
#   'you',
#   'least',
#   'was',
#   'you',
#   'is',
#   'was',
#   'it',
#   'was',
#   'bought',
#   'not',
#   'with',
#   'will',
#   'is',
#   'will',
#   'might',
#   'you',
#   "'ve",
#   'got',
#   'you',
#   "'m",
#   'was',
#   'jump',
#   "'ll",
#   'be',
#   'is',
#   'probably',
#   'would',
#   'am',
#   'is',
#   'you',
#   'wedges',
#   'allows',
#   'do',
#   '-',
#   'it',
#   'i',
#   'it',
#   "n't",
#   'getting',
#   "'m",
#   'i',
#   'instant',
#   'you',
#   'helps',
#   'headphones',
#   'have',
#   'probably',
#   'definitely',
#   'he',
#   'it',
#   'i',
#   'been',
#   'video',
#   'are',
#   'can',
#   'it',
#   'it',
#   'one'],
#  ('amazon', 'me'): ['it'],
#  ('had', 'in'): ['to', 'the', 'most'],
#  ('it', '<'): ['me'],
#  ('to', '2'): ['in', 'the', ','],
#  ('me', 'business'): ['<'],
#  ('in', 'days'): ['2', 'to'],
#  ('i', 'back-ups'): ['3'],
#  ('ordered', 'es'): ['apc'],
#  ('3', '500s'): ['back-ups'],
#  ('apc', 'on'): ['es'],
#  ('back-ups', 'the'): ['500s'],
#  ('es', 'recommendation'): ['on'],
#  ('500s', 'of'): ['the'],
#  ('on', 'an'): ['recommendation', 'sound'],
#  ('the', 'employee'): ['of'],
#  ('recommendation', 'of'): ['an'],
#  ('of', 'mine'): ['employee'],
#  ('an', 'who'): ['of'],
#  ('employee', 'used'): ['mine'],
#  ('of', 'to'): ['who',
#   'service',
#   'headphones',
#   'to',
#   'mouse',
#   'equipment',
#   'and',
#   '.',
#   'like',
#   'pair',
#   'suction',
#   'we',
#   'you',
#   'fm',
#   'photo',
#   'a',
#   'case',
#   'covered',
#   'check',
#   'sennheiser',
#   'deaf',
#   'who',
#   'who',
#   'even',
#   '(',
#   'games',
#   'logitech',
#   'covered',
#   'check',
#   'you',
#   'aiming'],
#  ('mine', 'work'): ['used'],
#  ('who', 'at'): ['to', 'any'],
#  ('used', 'apc'): ['work'],
#  ('to', '.'): ['at',
#   'good',
#   'it',
#   'proven',
#   'the',
#   'for',
#   'tape',
#   'and',
#   'the',
#   'counting',
#   'them',
#   'this',
#   'linux',
#   'the',
#   'manually',
#   'being',
#   'in',
#   'it',
#   'dvd',
#   'router',
#   'these',
#   'about',
#   'and',
#   'the',
#   'from',
#   'a',
#   'new',
#   'this',
#   'labeling',
#   "'s",
#   'used',
#   'high',
#   'the',
#   'within',
#   'zen',
#   'the',
#   'as',
#   'through',
#   '100+',
#   'pretty',
#   'with',
#   'extra',
#   'lastest',
#   'for',
#   'a',
#   'the',
#   'base',
#   'mitsubishi',
#   'scansnap',
#   'aware',
#   'this',
#   ':',
#   'other',
#   'other',
#   'some',
#   'cranked',
#   'up',
#   'the',
#   'cell',
#   'music',
#   'my',
#   'at',
#   'a',
#   'the',
#   'and',
#   'solidly',
#   'with',
#   'size',
#   'next',
#   'the',
#   'the',
#   'peoples',
#   'it',
#   'the',
#   'it',
#   'it',
#   'the',
#   'a',
#   'related',
#   'monster',
#   'my',
#   'same',
#   'the',
#   'electrical',
#   'one',
#   'this',
#   'the',
#   'two',
#   'snapped',
#   'accidental',
#   'digital',
#   '110',
#   'to',
#   'the',
#   'and',
#   'my',
#   'the',
#   'and',
#   'music',
#   'the',
#   'the',
#   'your',
#   'the',
#   'disabled',
#   'for',
#   'sony',
#   'used',
#   'and',
#   'the',
#   'after',
#   'my',
#   'them',
#   'denon',
#   'hp',
#   'about',
#   'the',
#   'the',
#   'it',
#   'this',
#   'car',
#   'at',
#   'my',
#   'a',
#   'second',
#   'fullest',
#   'or',
#   'converter',
#   'the',
#   'good',
#   'been',
#   'while',
#   'to',
#   'as',
#   'thus',
#   'the',
#   'in',
#   'this',
#   'direct',
#   'caller',
#   'it',
#   'it',
#   'and',
#   'another',
#   'this',
#   'and',
#   'it',
#   'it',
#   'them',
#   'a',
#   ',',
#   'navigation',
#   'other',
#   'about',
#   'i',
#   'less',
#   'audio',
#   'very',
#   '3',
#   'very',
#   'speed',
#   'to',
#   'arm',
#   'hp',
#   'wife',
#   'oregon',
#   'dark',
#   'as',
#   'it',
#   'with',
#   'either',
#   'modem',
#   'and',
#   'pretty',
#   'specific',
#   'that',
#   'as',
#   'certain',
#   'something'],
#  ('work', 'i'): ['apc', 'one', 'macs', '.', 'so'],
#  ('at', "'ve"): ['.', '.'],
#  ('apc', 'had'): ['i'],
#  ('.', 'them'): ["'ve",
#   'minuses',
#   'also',
#   'i',
#   'highly',
#   'powers',
#   "'ve",
#   'while',
#   'i',
#   'highly',
#   'frequently',
#   'have',
#   'first',
#   'then',
#   'satisfied',
#   'do',
#   'just',
#   'you'],
#  ('i', 'for'): ['had',
#   'my',
#   'this',
#   'had',
#   'impressed',
#   'in',
#   'in',
#   'had',
#   'have',
#   '&',
#   'go',
#   'used',
#   'recommand',
#   'this',
#   'an',
#   'usb',
#   'still',
#   'firmware',
#   'too',
#   'microsoft',
#   'use',
#   'their',
#   'used',
#   'medical',
#   'it',
#   'do',
#   'this',
#   'it',
#   'suggest',
#   'the',
#   'totally',
#   'expected',
#   'been',
#   'used',
#   'more',
#   'had',
#   "n't",
#   'this',
#   'bought',
#   'recomend',
#   'be',
#   'recommend',
#   'this',
#   'a',
#   'had',
#   'here',
#   'recommend',
#   'the',
#   'a',
#   'done',
#   "n't",
#   'this',
#   'it',
#   'aftermarket',
#   'had',
#   'local',
#   '2',
#   'a',
#   "n't",
#   'this',
#   'not',
#   'this',
#   'this',
#   'recommend',
#   'had',
#   'that',
#   'these',
#   "n't",
#   'owned',
#   'this',
#   'used',
#   'saving',
#   'had',
#   'it',
#   'had',
#   'this',
#   'had',
#   'used',
#   'used',
#   'used',
#   'had'],
#  ("'ve", 'about'): ['them', 'it', 'to', 'mine', 'it', 'it', 'it'],
#  ('had', 'a'): ['for',
#   'photo',
#   'for',
#   'going',
#   'monitor',
#   'expected',
#   'for',
#   'phone'],
#  ('them', 'month'): ['about'],
#  ('for', 'now'): ['a',
#   'a',
#   'two',
#   'a',
#   '8',
#   'zen',
#   '2',
#   '6-7',
#   'three',
#   'a',
#   'a',
#   'some',
#   '3',
#   'a',
#   'ht',
#   'two',
#   'little',
#   'a',
#   'a',
#   'a',
#   ',',
#   '4',
#   'a',
#   '8'],
#  ('about', 'without'): ['month'],
#  ('a', 'any'): ['now', 'playable', 'idea'],
#  ('month', 'problems'): ['without'],
#  ('now', '.'): ['any', 'no', '(', "'s", 'a', 'love'],
#  ('without', 'they'): ['problems'],
#  ('any', "'ve"): ['.', 'phone', '.'],
#  ('problems', 'functioned'): ['they'],
#  ('.', 'properly'): ["'ve"],
#  ('they', 'through'): ['functioned'],
#  ("'ve", 'a'): ['properly', 'it', 'this', 'known', 'one', 'it', 'heard'],
#  ('functioned', 'few'): ['through'],
#  ('properly', 'unexpected'): ['a'],
#  ('through', 'power'): ['few'],
#  ('a', 'interruptions'): ['unexpected'],
#  ('few', '.'): ['power', 'i', 'of'],
#  ('unexpected', 'i'): ['interruptions'],
#  ('power', "'ll"): ['.'],
#  ('interruptions', 'gladly'): ['i'],
#  ('.', 'order'): ["'ll"],
#  ('i', 'more'): ['gladly',
#   'to',
#   'be',
#   "n't",
#   "n't",
#   'probably',
#   'we',
#   'have',
#   'down'],
#  ("'ll", 'if'): ['order'],
#  ('gladly', 'the'): ['more'],
#  ('order', 'need'): ['if'],
#  ('more', 'arises'): ['the'],
#  ('if', '.'): ['need',
#   "'re",
#   'ask',
#   'at',
#   'are',
#   'ht',
#   'gps',
#   'anyway',
#   'want',
#   'own',
#   'are'],
#  ('the', 'pros'): ['arises', 'clockwise/counterclockwise', 'fi'],
#  ('need', ':'): ['.', 'one'],
#  ('arises', '-'): ['pros'],
#  ('.', 'large'): [':', 'i'],
#  ('pros', 'plug'): ['-'],
#  (':', 'spacing'): ['large'],
#  ('-', ','): ['plug', 'bose', 'construction', 'used', ','],
#  ('large', 'good'): ['spacing'],
#  ('plug', 'for'): [',', 'asio'],
#  ('spacing', 'power'): ['good'],
#  (',', 'adapters'): ['for', 'two'],
#  ('good', '-'): ['power'],
#  ('for', 'simple'): ['adapters', '.'],
#  ('power', 'design'): ['-'],
#  ('adapters', '-'): ['simple'],
#  ('-', 'long'): ['design'],
#  ('simple', 'cord'): ['-'],
#  ('design', 'cons'): ['long'],
#  ('-', ':'): ['cord'],
#  ('long', '-'): ['cons'],
#  ('cord', 'no'): [':'],
#  ('cons', 'line'): ['-'],
#  (':', 'conditioning'): ['no'],
#  ('-', '('): ['line', 'the', 'latitude', 'bass', 'are'],
#  ('no', 'usually'): ['conditioning'],
#  ('line', 'an'): ['('],
#  ('conditioning', 'expensive'): ['usually'],
#  ('(', 'option'): ['an'],
#  ('wish', 'a'): ['unit', 'had'],
#  ('the', 'separate'): ['had'],
#  ('unit', 'online/offline'): ['a'],
#  ('had', 'light'): ['separate'],
#  ('a', '.'): ['online/offline',
#   'blue',
#   'of',
#   'fm',
#   'solution',
#   'usb',
#   'blue',
#   'mouse',
#   'between',
#   'disc',
#   'weeks',
#   'cd',
#   'or',
#   'is',
#   'scraped',
#   'long',
#   'could',
#   'travel',
#   'forgotten',
#   'little',
#   'small',
#   'sharp',
#   'of',
#   'extra',
#   'lot',
#   'answering',
#   'ipod',
#   'complaint',
#   'itrip',
#   'clean',
#   'bit',
#   'hour',
#   'wireless',
#   'solid',
#   'new',
#   'finishing',
#   'of',
#   'built',
#   'larger',
#   'special',
#   'to',
#   '100',
#   'tube',
#   'battery',
#   'is',
#   'durable',
#   'phone',
#   'limited',
#   'as',
#   'this',
#   '*',
#   'kardon',
#   'battery',
#   'to',
#   'notebook',
#   'impressive',
#   'weeks',
#   'small',
#   'of',
#   'analog',
#   'volume',
#   'product',
#   'comes',
#   'of',
#   'of',
#   'sound',
#   'before',
#   'better',
#   'network',
#   'hard',
#   'music',
#   'of',
#   'of',
#   'of',
#   'recommended',
#   'sound',
#   'bonus',
#   'of',
#   'low',
#   'for',
#   'outgoing',
#   'answer',
#   'megapixel',
#   'of',
#   'installing',
#   'meter',
#   'long',
#   'compactflash',
#   'of',
#   'as',
#   'email-friendly',
#   'of',
#   'positive',
#   'as',
#   'of',
#   'program',
#   'recorder',
#   'of',
#   'metallic',
#   'price',
#   'sized',
#   'hard',
#   'of',
#   'realistic',
#   'new',
#   'home',
#   'days',
#   'bottle',
#   'months',
#   'speaker',
#   'years',
#   'laptop',
#   'so',
#   'of',
#   "''",
#   'bit',
#   'headset',
#   'time',
#   'commercial',
#   'for',
#   'should',
#   'or',
#   'transfer',
#   'branded',
#   'for',
#   'drink',
#   'background',
#   'direction',
#   'clear',
#   'dirt',
#   'light',
#   'equalizer',
#   'discount',
#   'volume',
#   'straightforward',
#   'more',
#   'negative',
#   ',',
#   'cordless',
#   'of',
#   'of',
#   'k-band',
#   'storage',
#   'dual',
#   'ipod',
#   'of',
#   'fashion',
#   'to',
#   'form',
#   'durable',
#   'distance',
#   'of',
#   'do'],
#  ('separate', 'when'): ['light'],
#  ('online/offline', 'power'): ['.'],
#  ('light', 'to'): ['when', 'not', 'not'],
#  ('.', 'the'): ['power',
#   'really',
#   'video',
#   'quality',
#   'works',
#   ',',
#   'product',
#   ',',
#   'course',
#   'i',
#   'agree',
#   'usually',
#   'bank',
#   'seems',
#   'receiver',
#   'i',
#   'this',
#   'also',
#   'seems',
#   'also',
#   ')',
#   'stay',
#   'fun',
#   'durability',
#   "n't",
#   'you',
#   'hesitated',
#   'the',
#   'panasonic',
#   'also',
#   '600',
#   'i',
#   'so',
#   'thing',
#   "'re",
#   'still',
#   'all',
#   'recommended',
#   'fact',
#   'advantage',
#   "'s",
#   'far',
#   'unsatisfied',
#   'i',
#   'than',
#   'hd',
#   'to',
#   'enjoy',
#   'handy',
#   'only',
#   'are',
#   'headset',
#   'has',
#   'range',
#   'cushioning',
#   "'ve",
#   'also',
#   'the',
#   '...',
#   'said',
#   'burner',
#   'have',
#   'why',
#   ',',
#   'their',
#   'i',
#   'a',
#   'case',
#   "'ll",
#   'can',
#   'have',
#   'keypad',
#   'i',
#   'get',
#   'initially',
#   'are',
#   'never',
#   "n't",
#   'bottom',
#   'resolution',
#   'product',
#   'going',
#   'pad',
#   'was',
#   'out',
#   'received',
#   'only',
#   ',',
#   'all',
#   'you',
#   'also',
#   'just',
#   'like',
#   'design',
#   'would',
#   'now',
#   'you',
#   'i',
#   'far',
#   'price',
#   ',',
#   'satisfied',
#   'aquisition',
#   'many',
#   'also',
#   'just',
#   'i',
#   'gripes',
#   'notes',
#   'performed',
#   'i',
#   'happens',
#   'is',
#   'nowhere',
#   'i',
#   'i',
#   "'s",
#   'when',
#   'as',
#   'really',
#   'play',
#   'also',
#   'completely',
#   'now',
#   'just',
#   'we',
#   'than',
#   'this',
#   'one',
#   'effectively',
#   'find',
#   'first',
#   "'d",
#   'would',
#   "'m",
#   'resisted',
#   'playlists',
#   'then',
#   "'ll",
#   'i',
#   "'ve",
#   'out',
#   ',',
#   'will',
#   '2',
#   'ones',
#   'addition',
#   'can',
#   'highly',
#   'value',
#   'even',
#   'switching',
#   "'s",
#   'lot',
#   "'m",
#   'has',
#   'actually',
#   'like',
#   'i',
#   'can',
#   'settled',
#   'immediately',
#   'week',
#   ',',
#   'hinge',
#   'focused',
#   'rumor',
#   'completely',
#   'yet',
#   'also',
#   'still',
#   'wish',
#   'also',
#   'to',
#   'reason',
#   'have',
#   'also',
#   'particularly',
#   'support',
#   'fully',
#   'would',
#   'thoughts',
#   ',',
#   'also',
#   'face',
#   'back',
#   'becomes',
#   ',',
#   'downside',
#   'can',
#   'neck',
#   'quality',
#   'out',
#   'to',
#   'bought',
#   'addition',
#   'addition',
#   'resulted',
#   'to',
#   'crispness',
#   'started',
#   'i',
#   'cobra',
#   'size',
#   'this',
#   'seems',
#   'bass',
#   'think',
#   'and',
#   'sound',
#   'only',
#   'places',
#   'travel',
#   'notes',
#   'performed',
#   'does',
#   'was',
#   'price',
#   'v3m',
#   'program',
#   'i',
#   'sure',
#   'also',
#   'can',
#   'me',
#   'pleased',
#   'money',
#   'that',
#   'three',
#   'have',
#   'do',
#   ')',
#   'fact',
#   'easily',
#   'really',
#   "'ve",
#   'button',
#   "'m",
#   'have'],
#  ('when', 'unit'): ['to'],
#  ('power', 'is'): ['the'],
#  ('to', 'missing'): ['unit'],
#  ('the', ','): ['is',
#   'is',
#   'one',
#   'looked',
#   'screen',
#   'lx',
#   'buckle',
#   '6',
#   ',',
#   ',',
#   'problem',
#   'mono',
#   'vinyl',
#   'to',
#   ',',
#   'will',
#   'works',
#   'is',
#   '...',
#   'is',
#   'i',
#   'is',
#   'profile',
#   "''",
#   'is',
#   'menu',
#   '.',
#   '.',
#   'required',
#   'hour',
#   'is',
#   'is',
#   'run',
#   'fully',
#   'is',
#   '.',
#   'is',
#   'any',
#   'generation',
#   'is',
#   'is',
#   '(',
#   'technology',
#   'often',
#   'produces',
#   'is',
#   ',',
#   'u3',
#   'is',
#   'is',
#   ',',
#   'of',
#   ',',
#   'or',
#   'as',
#   'inch',
#   'clip',
#   ',',
#   'of',
#   ',',
#   'very',
#   'batteries',
#   'and',
#   ',',
#   'or',
#   'is',
#   'at',
#   '.',
#   'from',
#   '.',
#   'and',
#   'experience',
#   ',',
#   '.',
#   ',',
#   'one',
#   'is',
#   'was',
#   'tilt',
#   '.',
#   'feels',
#   'av',
#   'decade',
#   ',',
#   'you',
#   'and/or',
#   'is',
#   'gig',
#   'office',
#   '.',
#   "'s",
#   'stars',
#   'right',
#   "''",
#   'at',
#   'windows',
#   '.',
#   'speaker',
#   '.',
#   'for',
#   'automatic',
#   'was',
#   'with',
#   ',',
#   'is',
#   'works',
#   'control',
#   'print',
#   'of',
#   '.',
#   'new',
#   '.',
#   'is',
#   'by',
#   'by',
#   'are',
#   'version',
#   'stuff',
#   'is',
#   'one',
#   ',',
#   'or',
#   ',',
#   'panasonic',
#   'pops',
#   'and',
#   '.',
#   'fold',
#   'battery',
#   'is',
#   'ans',
#   'with',
#   'earpiece',
#   '.',
#   'has',
#   'setup',
#   'works',
#   'clip',
#   'couple',
#   'of',
#   'document',
#   ':',
#   'is',
#   'you',
#   '!',
#   'one',
#   'are',
#   ',',
#   'and',
#   ':',
#   '.',
#   'back',
#   'logitech',
#   'for',
#   '.',
#   ',',
#   'screen',
#   ',',
#   'of',
#   'tiles',
#   "'s",
#   'recorder',
#   '.',
#   'dry',
#   ',',
#   'for',
#   'process',
#   'photo',
#   'i'],
#  ('unit', 'the'): ['missing',
#   'also',
#   'off',
#   'in',
#   'was',
#   '.',
#   'one',
#   'to',
#   'one',
#   'then',
#   'next',
#   'all'],
#  ('is', 'single'): [','],
#  ('missing', 'red'): ['the'],
#  (',', 'light'): ['single', 'the'],
#  ('the', 'turns'): ['red', 'the', 'guide'],
#  ('single', 'off'): ['light'],
#  ('red', 'only'): ['turns'],
#  ('light', 'when'): ['off', 'on'],
#  ('turns', 'the'): ['only'],
#  ('off', 'warning'): ['when'],
#  ('only', 'sounds'): ['the'],
#  ('when', '.'): ['warning',
#   'go',
#   'is',
#   'unplug',
#   'day',
#   'in',
#   'bought',
#   'between',
#   'into',
#   'my',
#   'use',
#   'for',
#   'is'],
#  ('the', 'the'): ['sounds',
#   'intime',
#   'line',
#   'size',
#   'is',
#   'issue',
#   'time',
#   'quality',
#   'screen',
#   'certainly',
#   'weekend',
#   'holes',
#   'that',
#   '.',
#   'price',
#   'attaching',
#   'so',
#   ',',
#   'to',
#   'lettering',
#   'shocks',
#   'that',
#   'velocity',
#   ',',
#   'paste',
#   'i',
#   'to',
#   'or',
#   'earphones',
#   '.',
#   'level',
#   'also',
#   'selections',
#   'out',
#   'going',
#   'to',
#   'both',
#   '.',
#   'version',
#   'drive',
#   'away',
#   'connection',
#   'screens',
#   '(',
#   'bang',
#   'description',
#   'works',
#   ',',
#   'does',
#   'of',
#   'and',
#   'or',
#   'to',
#   'of',
#   'tracking',
#   'now',
#   'one',
#   'next',
#   'after',
#   'thing',
#   'end',
#   'end',
#   'ends',
#   'who',
#   'before',
#   'problem',
#   ',',
#   'part',
#   'person',
#   'was',
#   'of',
#   'player',
#   'ex71',
#   'traveling',
#   'are',
#   'ones',
#   'wheel',
#   'parts',
#   'price',
#   'gb',
#   'batch',
#   ',',
#   'line',
#   'mail',
#   'mouse',
#   'quality',
#   "'s",
#   'comfortable',
#   ',',
#   'or',
#   'will',
#   'of',
#   'job',
#   'place',
#   'rest',
#   'or',
#   'life',
#   'handset',
#   'restrictions',
#   'ink',
#   'surface',
#   'cranium',
#   'capacity',
#   'drawback',
#   '.',
#   'produced',
#   'away',
#   'size',
#   'here',
#   'used',
#   'cd',
#   'of',
#   'list',
#   'call',
#   'id',
#   'yesterday',
#   'back',
#   'violins',
#   'down',
#   'drive',
#   'to',
#   'anywhere',
#   'came',
#   'difference',
#   'up',
#   'setting',
#   'rate',
#   '.',
#   'simply',
#   'antenna',
#   'drawbacks',
#   ',',
#   'v',
#   '(',
#   'exception',
#   '(',
#   'to',
#   'are',
#   'and',
#   'in',
#   'out',
#   'ever',
#   'life',
#   'buttons',
#   'sitting',
#   'gamepad',
#   'time',
#   'way',
#   'before',
#   'barn',
#   'to',
#   'key',
#   ';',
#   'device',
#   'quality',
#   'are',
#   'place',
#   'nano',
#   'corners',
#   ',',
#   'to',
#   'end',
#   'feature',
#   'that',
#   'kit',
#   'receiver',
#   'one',
#   '.',
#   'place',
#   'ability',
#   "'s",
#   'side',
#   'speakers',
#   'cable',
#   'and',
#   'stating',
#   'case',
#   'paper',
#   'included',
#   ',',
#   'tools',
#   'experience',
#   'adjacent',
#   'config',
#   'thing',
#   '.',
#   'worked',
#   'problem',
#   'is',
#   'screen',
#   'size',
#   'attaches',
#   'and',
#   'location',
#   ',',
#   'maps',
#   'is',
#   'noise',
#   'came',
#   'to',
#   'of',
#   'simply',
#   'both',
#   'analog',
#   'with',
#   '(',
#   'to',
#   'cable',
#   'and',
#   'to',
#   'one',
#   'interface',
#   'plug',
#   '.',
#   'reviews',
#   'sensor',
#   'much',
#   'available',
#   'basically',
#   'service',
#   'while',
#   'to',
#   'flap',
#   'tab',
#   'thing',
#   'thing',
#   'bit',
#   'stations',
#   'accent',
#   'voice',
#   'cable',
#   'price',
#   'cables',
#   'version',
#   'deals',
#   'one',
#   'remote',
#   'rooms',
#   'part',
#   'light',
#   'was',
#   'format',
#   'mode',
#   '.',
#   'here',
#   'and',
#   'is',
#   'going',
#   'ear',
#   'circuit',
#   'is',
#   'overture',
#   'efficiency',
#   'and',
#   'features',
#   'that',
#   'player',
#   'tag',
#   'reviews',
#   'onstage',
#   'broke',
#   'consideration',
#   'life',
#   'caused',
#   'quality',
#   'cushions',
#   'pair',
#   'protection',
#   'area',
#   'shift',
#   'component',
#   'piece',
#   'logo',
#   'display',
#   'unit',
#   'half',
#   'life',
#   'seat',
#   'roar',
#   'engines',
#   'adapter',
#   'case',
#   'must',
#   'case',
#   'one',
#   'is',
#   ',',
#   'door',
#   'range',
#   'garage',
#   'end',
#   'even',
#   'light',
#   '.',
#   'case',
#   'part',
#   '250',
#   'photos',
#   'by',
#   'unpleasant',
#   'buttons',
#   'and',
#   ')',
#   'capable',
#   ',',
#   'falls',
#   'and',
#   ',',
#   'and',
#   'soon',
#   'to',
#   'compartment',
#   'supplied',
#   'song',
#   ',',
#   'router',
#   ',',
#   'time',
#   'ear',
#   'version',
#   'item',
#   'one',
#   'adapter',
#   ',',
#   'end',
#   'slot',
#   'sd',
#   'canal',
#   'feel',
#   ',',
#   'effect',
#   'right',
#   'worked',
#   'out',
#   'settings',
#   'away',
#   'case',
#   ',',
#   'but',
#   'except',
#   'plug',
#   ',',
#   'clickwheel',
#   ',',
#   'choice',
#   '.',
#   'guru',
#   'and',
#   'to',
#   'was',
#   'quality',
#   'money',
#   'is',
#   'placed',
#   'reviews',
#   'function',
#   'downside',
#   'is',
#   'surface',
#   ',',
#   'song',
#   'cartridges',
#   'version',
#   ')',
#   'construction',
#   '(',
#   'button',
#   '.',
#   'feet',
#   'i',
#   'feel',
#   'features',
#   'end',
#   'end',
#   'point',
#   'was',
#   'jack',
#   'though',
#   'are',
#   'connection'],
#  ('warning', 'warning'): ['.'],
#  ('sounds', 'sound'): ['the'],
#  ('.', 'is'): ['warning',
#   'the',
#   'ultra',
#   'removable',
#   'picture',
#   'audio',
#   '2700mah',
#   'pressure',
#   'photo',
#   'someone',
#   'the',
#   'bad',
#   'only',
#   'dpi',
#   'only',
#   ',',
#   'disappointing',
#   'only',
#   'only',
#   'only',
#   ':',
#   ':',
#   'only',
#   'newer',
#   ',',
#   'remote',
#   ')',
#   'the',
#   'flexible',
#   'battery',
#   'image',
#   'i',
#   ',',
#   'buying',
#   'only',
#   "'s",
#   'line',
#   'quickly',
#   'you',
#   'the',
#   'dashboard',
#   'battery',
#   'thx',
#   'setpoint',
#   'wrist',
#   ',',
#   'low',
#   'setup',
#   'only',
#   'ipod',
#   'optical',
#   'only',
#   'sound',
#   'last',
#   'the',
#   'sound',
#   'each',
#   'think',
#   'number',
#   'sound',
#   'the',
#   'middle',
#   ',',
#   'only',
#   'the',
#   'caller',
#   'bose',
#   'i',
#   'dash',
#   ',',
#   'sound',
#   'sound',
#   'sound',
#   'only',
#   'the',
#   'new',
#   '$',
#   'cradle',
#   'sound',
#   'unexpected',
#   'best',
#   'this',
#   'the',
#   'sound',
#   'real',
#   'the',
#   'usb',
#   'other',
#   'usb',
#   ',',
#   '9',
#   'on',
#   'great',
#   ',',
#   "'s",
#   'record',
#   'provided',
#   'best',
#   'blue',
#   'leather',
#   'screen',
#   'other',
#   'that',
#   'best',
#   'phone',
#   ',',
#   'picture',
#   'rf',
#   '30',
#   'biggest',
#   'course',
#   'user',
#   'power',
#   'video',
#   ',',
#   'picture',
#   'user',
#   'remote',
#   ',',
#   'usb',
#   'the',
#   'interesting',
#   'linksys',
#   'voice',
#   'to',
#   'part',
#   'think',
#   'controls',
#   'now',
#   'video',
#   ',',
#   'cmss',
#   'it',
#   'the',
#   'system',
#   'that',
#   'sound',
#   'recording',
#   ',',
#   'surround',
#   "'s",
#   'plus',
#   'mic',
#   'audio',
#   'only',
#   ',',
#   ')',
#   ',',
#   'profiler',
#   'contrast',
#   'home',
#   ',',
#   'best',
#   'turnaround',
#   'means',
#   'control',
#   'folding',
#   'middle',
#   'sound',
#   'only',
#   'traffic',
#   'the',
#   'amazing',
#   "'s",
#   'sound',
#   'this',
#   'the',
#   ',',
#   'tech',
#   'first',
#   'detection',
#   'helped',
#   'only',
#   'reason',
#   'we',
#   'face',
#   'orbit',
#   ',',
#   'photo',
#   'd-pad',
#   'case',
#   'obvious',
#   'rechargeable',
#   'nice',
#   'speakerphone'],
#  ('the', 'like'): ['sound',
#   'sounded',
#   'and',
#   'brand',
#   'sound',
#   '.',
#   "''",
#   '.',
#   '.',
#   '.',
#   'screen',
#   '.'],
#  ('warning', 'a'): ['is', 'advance'],
#  ('sound', 'lot'): ['like', 'a'],
#  ('is', 'of'): ['a',
#   'a',
#   'the',
#   'awsome',
#   'the',
#   'than',
#   'a',
#   'excellent',
#   'second',
#   'second',
#   'the',
#   'the',
#   'a',
#   'good',
#   'a',
#   '.',
#   '.',
#   'great',
#   'a',
#   'sheet',
#   '.',
#   '.',
#   'every',
#   'the',
#   'slight',
#   'by',
#   'because',
#   'little',
#   'most',
#   'a',
#   'a',
#   'the'],
#  ('like', 'sounds'): ['lot'],
#  ('a', 'you'): ['of',
#   'heavy',
#   'fiddly',
#   'tricky',
#   'trickier',
#   'plus',
#   'belt',
#   'rms',
#   'choice',
#   'price',
#   'audiophile',
#   '!',
#   'floor',
#   'intercom',
#   'charge',
#   '650',
#   'payable',
#   'picture',
#   'buy',
#   'of',
#   '.',
#   'rate',
#   'remote',
#   'cable',
#   'which',
#   'more',
#   '.',
#   'addition',
#   'seal',
#   'light',
#   '.',
#   'that',
#   'player',
#   'case',
#   'frustrating',
#   'head',
#   'payable',
#   '(',
#   'better',
#   'clip',
#   ',',
#   'clip',
#   'mouse'],
#  ('lot', 'hear'): ['sounds'],
#  ('of', 'in'): ['you',
#   'volume',
#   'old',
#   'holes',
#   'the',
#   'song',
#   'ports',
#   'is',
#   'my',
#   '(',
#   'q9b',
#   'handsets',
#   'and'],
#  ('sounds', 'the'): ['hear', 'better', '!'],
#  ('you', 'house'): ['in'],
#  ('hear', 'so'): ['the'],
#  ('in', 'it'): ['house',
#   'succession',
#   'specs',
#   'to',
#   'you',
#   'xp',
#   'skill',
#   '.',
#   ',',
#   'computer',
#   'dark',
#   'pocket',
#   'case',
#   'song',
#   'song',
#   'rain',
#   'case',
#   'store',
#   'i',
#   'that',
#   'comparison',
#   'i',
#   'mount',
#   ',',
#   'america',
#   'format',
#   'you',
#   'to',
#   'car',
#   'house',
#   'even',
#   'case',
#   'cradle',
#   'plane',
#   'ear',
#   'to',
#   'car',
#   'back',
#   'microsd',
#   'car',
#   'yard'],
#  ('the', 'is'): ['so',
#   'menu',
#   'def',
#   '6x11',
#   'sensitivity',
#   'one',
#   'strap',
#   "'case",
#   'allowed',
#   'slinger',
#   'down',
#   '.',
#   'of',
#   ',',
#   'sound',
#   'rubber',
#   '.',
#   '.',
#   'behind',
#   'and',
#   'well',
#   'rebate',
#   'superior',
#   ',',
#   'because',
#   'drive',
#   'color',
#   'battery',
#   'cancellation',
#   'cooler',
#   'connector',
#   'hand',
#   ',',
#   'functionality',
#   'hard',
#   'to',
#   'start',
#   ',',
#   'radio',
#   '.',
#   'where',
#   'package',
#   'manual',
#   'and',
#   'green',
#   'says',
#   'real',
#   'in',
#   'in',
#   'station',
#   'lag',
#   "'s",
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   ';',
#   'draw',
#   'zoom',
#   '.',
#   'meter',
#   ':',
#   ',',
#   'possible',
#   'in',
#   'and',
#   ',',
#   'poi',
#   'wheel',
#   '.',
#   'as',
#   'hd',
#   '.',
#   'draw',
#   'tray',
#   'sound',
#   'cup',
#   '15',
#   'case',
#   'shipping',
#   'cruzer',
#   'u3',
#   'cruzer',
#   '.',
#   'so',
#   '$',
#   'down',
#   'of',
#   ':',
#   'volume',
#   'purple',
#   'thing',
#   'in',
#   'and',
#   'heads',
#   'telephone',
#   'document',
#   '.',
#   'or',
#   '.',
#   'radio',
#   'this',
#   'phone',
#   '.',
#   '.',
#   'but',
#   'well',
#   'through',
#   '(',
#   'place',
#   'draw',
#   'card',
#   ',',
#   'compartment',
#   'charging',
#   'port'],
#  ('house', "n't"): ['it'],
#  ('so', 'always'): ['is'],
#  ('it', 'easy'): ["n't",
#   'fast',
#   'configuration',
#   ',',
#   'simplicity',
#   'so',
#   'a',
#   'really',
#   'great',
#   'light'],
#  ('is', 'to'): ['always',
#   'real',
#   'you',
#   'little',
#   'in',
#   'when',
#   ',',
#   'little',
#   '.',
#   'for',
#   'right',
#   'great',
#   'and',
#   'software',
#   'too',
#   'a',
#   'serious',
#   'and',
#   '...',
#   'i',
#   'most',
#   'to',
#   'you',
#   'last',
#   'especially',
#   'to',
#   ',',
#   'great',
#   'big',
#   'for',
#   'bit',
#   'best',
#   'great',
#   ',',
#   'just',
#   'bit',
#   'the',
#   'long',
#   'only',
#   '.',
#   'and',
#   'last',
#   'and',
#   'a',
#   'the',
#   ',',
#   'that',
#   'it',
#   'ideal'],
#  ("n't", 'tell'): ['easy'],
#  ('always', 'what'): ['to'],
#  ('easy', 'is'): ['tell', 'on-screen', 'use', 'overall'],
#  ('to', 'happening'): ['what', 'this'],
#  ('cheaper', 'cases'): ['thick'],
#  ('than', 'and'): ['cd', 'gravis', 'need', 'zune', '.', 'prologic'],
#  ('thick', 'less'): ['cases'],
#  ('cd', 'prone'): ['and'],
#  ('cases', 'to'): ['less'],
#  ('and', 'breakage'): ['prone'],
#  ('less', ','): ['to', '$'],
#  ('prone', 'these'): ['breakage'],
#  ('to', '``'): [',', 'iriver', 'up', 'their', 'so'],
#  ('breakage', 'slim'): ['these'],
#  (',', "''"): ['``', 'a', '``', 'size', '``'],
#  ('these', 'cases'): ['slim'],
#  ('``', 'by'): ["''"],
#  ('slim', 'memorex'): ['cases'],
#  ("''", 'protect'): ['by'],
#  ('cases', 'your'): ['memorex'],
#  ('by', 'cds'): ['protect'],
#  ('memorex', '.'): ['your'],
#  ('protect', 'most'): ['cds'],
#  ('your', 'buyers'): ['.'],
#  ('cds', 'will'): ['most'],
#  ('.', 'get'): ['buyers',
#   'have',
#   'didnt',
#   'have',
#   "'d",
#   'would',
#   ',',
#   'i',
#   'notebooks',
#   'let',
#   "'s",
#   'able',
#   'this',
#   'did',
#   'tried',
#   'good',
#   "'ll",
#   'ca',
#   'need',
#   'did'],
#  ('most', 'them'): ['will'],
#  ('buyers', 'for'): ['get'],
#  ('will', 'use'): ['them', 'when', 'how'],
#  ('get', 'in'): ['for', 'slight'],
#  ('them', 'cd'): ['use'],
#  ('for', 'or'): ['in', 'big', 'that', 'pair', 'small'],
#  ('use', 'dvd'): ['cd', 'as'],
#  ('in', 'burning'): ['or'],
#  ('cd', ','): ['dvd', 'just', 'the', ',', 'mp3', 'works'],
#  ('or', 'and'): ['burning', 'on', ')', 'photo', 'drive', 'store'],
#  ('dvd', 'these'): [','],
#  ('burning', 'are'): ['and'],
#  (',', 'an'): ['these',
#   'it',
#   'you',
#   "'s",
#   'you',
#   'precise',
#   'live',
#   "'d",
#   "'m",
#   'is',
#   'say'],
#  ('and', 'affordable'): ['are'],
#  ('these', 'choice'): ['an'],
#  ('are', 'from'): ['affordable'],
#  ('an', 'a'): ['choice', 'player', 'evaluation'],
#  ('affordable', 'quality'): ['from'],
#  ('choice', 'company'): ['a'],
#  ('from', 'for'): ['quality', 'unit', 'amazon'],
#  ('a', 'that'): ['company',
#   'player',
#   'surprised',
#   'taken',
#   'instead',
#   'one',
#   ',',
#   'value',
#   'leather',
#   'printing',
#   'freeware',
#   'simple',
#   'performance',
#   'of',
#   'to',
#   'dvd',
#   'speaker',
#   'warm',
#   'job',
#   'bigger',
#   'dollar',
#   'enhanced',
#   'rubber',
#   "''",
#   'for',
#   'to',
#   'of',
#   'much',
#   'plastic',
#   'fp2100',
#   'basic'],
#  ('quality', 'purpose'): ['for'],
#  ('company', '.'): ['that'],
#  ('for', 'you'): ['purpose',
#   '?',
#   'twenty',
#   '.',
#   ',',
#   '.',
#   ',',
#   'cost',
#   'matter',
#   'antenna',
#   'xbox',
#   'callers',
#   '.',
#   '!',
#   'receiver',
#   'price',
#   '.',
#   'navigation',
#   'price',
#   'price',
#   'price',
#   '20'],
#  ('that', 'may'): ['.', 'may', "'"],
#  ('purpose', 'want'): ['you'],
#  ('.', 'to'): ['may',
#   'is',
#   'is',
#   'has',
#   'was',
#   'sure',
#   'definitely',
#   'set',
#   'person',
#   'just',
#   'was',
#   'never',
#   'it',
#   'was',
#   'is',
#   ',',
#   'it',
#   'allows',
#   'is',
#   'came',
#   'is',
#   'is',
#   'you',
#   'recommendation',
#   'went',
#   'just',
#   'received',
#   'then',
#   '2.',
#   'has',
#   "'m",
#   'imac',
#   'are',
#   'gel',
#   'they',
#   'i',
#   'huge',
#   'you',
#   'you',
#   'might',
#   'brought',
#   'also',
#   'work',
#   'cable',
#   'sound',
#   'you',
#   'the',
#   'be',
#   'only',
#   'you',
#   'also',
#   'i',
#   'one',
#   'have',
#   'i',
#   'more',
#   'finally',
#   'then',
#   'call',
#   'am',
#   'never',
#   'recomendation',
#   'not',
#   'i',
#   'is',
#   'is',
#   'finally',
#   'is',
#   'am',
#   'bought',
#   'idea',
#   'is',
#   'really',
#   'are',
#   'just',
#   'never',
#   'when',
#   'you',
#   'you',
#   'am',
#   'will',
#   'would',
#   'lengthy',
#   'i',
#   'i',
#   'just',
#   "'s",
#   'was',
#   "'ll",
#   'was',
#   "n't",
#   'i',
#   'only',
#   'never',
#   'of',
#   "'d",
#   'is',
#   'is',
#   'the',
#   'was',
#   'allows',
#   'you',
#   'did',
#   'printer',
#   'you',
#   'being',
#   'the',
#   'was',
#   'is',
#   'only',
#   ':',
#   'just',
#   "'ll",
#   'connection',
#   'last',
#   'signal',
#   'had',
#   'am',
#   'may',
#   'took',
#   'recommend',
#   'not',
#   'from',
#   'not',
#   "'s",
#   'is',
#   'you',
#   'is',
#   'you',
#   "'ve",
#   'cord',
#   'k26p',
#   'i',
#   'they',
#   'recommended',
#   'was',
#   'bit',
#   "n't",
#   'is',
#   'you',
#   'will',
#   'are',
#   'purchased',
#   'it',
#   'look',
#   'i',
#   'allows',
#   "'s",
#   'purchased',
#   'gas',
#   'rollers',
#   'only',
#   'you',
#   'lives',
#   'headphone',
#   'only',
#   'bought',
#   'never',
#   'it',
#   'use',
#   'you',
#   'i',
#   'switched',
#   '``',
#   'forced',
#   'only',
#   'was',
#   'i',
#   'printers'],
#  ('you', 'consider'): ['want', 'want', 'wan'],
#  ('may', 'larger'): ['to'],
#  ('want', 'cases'): ['consider'],
#  ('to', 'depending'): ['larger'],
#  ('consider', 'on'): ['cases'],
#  ('larger', 'your'): ['depending'],
#  ('cases', 'tastes'): ['on'],
#  ('depending', ','): ['your', 'the', 'the'],
#  ('on', 'but'): ['tastes',
#   'sony',
#   'viewsonic',
#   'belt',
#   'web',
#   'list',
#   'either',
#   'list',
#   'cd',
#   'market'],
#  ('your', 'otherwise'): [','],
#  ('tastes', 'these'): ['but'],
#  (',', 'will'): ['otherwise',
#   'little',
#   'because',
#   'think',
#   'your',
#   'piano',
#   'from',
#   'beach',
#   'the',
#   'wireless'],
#  ('but', 'probably'): ['these'],
#  ('otherwise', 'satisfy'): ['will'],
#  ('these', 'your'): ['probably', "n't", 'will'],
#  ('will', 'needs'): ['satisfy'],
#  ('hi', 'mb'): ['brought'],
#  ('i', 'kingston'): ['256'],
#  ('brought', 'sd'): ['mb'],
#  ('256', 'card'): ['kingston', 'kingston'],
#  ('mb', 'from'): ['sd', 'digital'],
#  ('kingston', 'amazon.com'): ['card'],
#  ('sd', 'recently'): ['from'],
#  ('card', '.'): ['amazon.com', 'the', 'my', 'too', 'the', '1'],
#  ('from', 'according'): ['recently'],
#  ('amazon.com', 'to'): ['.'],
#  ('recently', 'my'): ['according'],
#  ('.', 'openion'): ['to'],
#  ('according', 'amazon'): ['my'],
#  ('to', 'is'): ['openion',
#   '.',
#   'the',
#   'your',
#   'the',
#   'while',
#   'that',
#   ',',
#   ',',
#   ',',
#   ',',
#   'this',
#   '.',
#   'up',
#   'if',
#   'indash',
#   'printing',
#   'this',
#   'mp3',
#   'as',
#   '.',
#   ',',
#   'if',
#   ',',
#   '.',
#   "''",
#   'voice'],
#  ('my', 'one'): ['amazon', 'tv', 'purchased', '.', 'was'],
#  ('openion', 'of'): ['is'],
#  ('amazon', 'the'): ['one', 'complain', 'description', 'you', 'almost', ','],
#  ('is', 'best'): ['of', 'of', 'far', 'slow', 'from', 'of', 'far'],
#  ('one', 'online'): ['the'],
#  ('of', 'shopping'): ['best'],
#  ('the', 'market'): ['online'],
#  ('best', ','): ['shopping', 'to', 'i', 'prints', 'with'],
#  ('online', 'they'): ['market'],
#  ('shopping', 'deliver'): [','],
#  ('market', 'the'): ['they', 'days'],
#  (',', 'products'): ['deliver'],
#  ('they', 'intime'): ['the'],
#  ('deliver', 'and'): ['products'],
#  ('products', 'items'): ['and'],
#  ('intime', 'i'): ['the'],
#  ('and', 'brought'): ['items'],
#  ('the', 'so'): ['i',
#   ')',
#   'you',
#   'box',
#   'plane',
#   'control',
#   'even',
#   'during',
#   'connection',
#   'are',
#   'isolation',
#   'anyway',
#   'channel',
#   'later',
#   'quality',
#   'to',
#   'up',
#   'jacks',
#   'is',
#   'setup',
#   'discription',
#   'version',
#   'anyway',
#   ',',
#   ')',
#   'column',
#   'web',
#   'to',
#   'is',
#   'keeps',
#   '(',
#   'screen',
#   'internet'],
#  ('items', 'far'): ['brought'],
#  ('i', 'are'): ['so', 'most', 'if', 'most', 'say', 'the'],
#  ('brought', 'working'): ['far'],
#  ('so', 'very'): ['are', 'i', 'opened', 'its'],
#  ('far', 'well'): ['working'],
#  ('working', '256'): ['well'],
#  ('very', 'mb'): ['.'],
#  ('well', 'kingston'): ['256'],
#  ('.', 'sd'): ['mb', 'good'],
#  ('mb', 'working'): ['sd'],
#  ('kingston', 'very'): ['card'],
#  ('sd', 'good'): ['working'],
#  ('card', 'with'): ['very'],
#  ('working', 'out'): ['good'],
#  ('very', 'giving'): ['with'],
#  ('good', 'any'): ['out', 'of'],
#  ('with', 'problem'): ['giving'],
#  ('out', '.'): ['any',
#   'as',
#   'slipping',
#   '.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'date',
#   'dvi',
#   'an',
#   'color',
#   'is',
#   'the',
#   'causes',
#   'pretty',
#   'good',
#   'the',
#   'the',
#   'range',
#   'the'],
#  ('giving', 'one'): ['problem'],
#  ('any', 'can'): ['.'],
#  ('problem', 'always'): ['one'],
#  ('.', 'go'): ['can', '`', 'can', 'ca', 'ca', 'can'],
#  ('one', 'to'): ['always',
#   'alows',
#   'to',
#   'be',
#   'type',
#   'be',
#   'good',
#   'i',
#   'much',
#   'specifically'],
#  ('can', 'amazon'): ['go'],
#  ('always', 'for'): ['to'],
#  ('go', 'online'): ['amazon'],
#  ('to', 'shopping'): ['for'],
#  ('amazon', '.'): ['online', 'tiger', 'replaced', 'free'],
#  ('for', 'bye'): ['shopping'],
#  ('online', 'kira'): ['.'],
#  ('this', '.'): ['was',
#   'works',
#   'not',
#   "n't",
#   'is',
#   'card',
#   'and',
#   'them',
#   'no',
#   'small',
#   'on',
#   'is',
#   'of',
#   'an',
#   'for',
#   'is',
#   'of',
#   'of',
#   'for',
#   'for',
#   'a',
#   'totally',
#   'was',
#   'as',
#   'is',
#   'is',
#   'great',
#   'is',
#   'works',
#   'to',
#   'is',
#   'to',
#   'does',
#   'uses',
#   'is',
#   'is',
#   '4',
#   'works',
#   'my',
#   'and',
#   'perfect',
#   'for',
#   'too',
#   'worth',
#   'really',
#   'speaker',
#   'from',
#   'radio',
#   'does',
#   'the',
#   'myself',
#   'pretty',
#   'are'],
#  ('product', 'it'): ['perfect', 'is', 'stars', 'you', 'even', 'you'],
#  ('was', "'s"): ['.', 'of', 'for'],
#  ('perfect', 'a'): ['it', 'i'],
#  ('.', 'sturdy'): ["'s", 'and'],
#  ('it', 'case'): ['a', 'with', 'of', 'in', 'in', 'a', 'a', '.'],
#  ("'s", 'that'): ['sturdy',
#   'a',
#   'getting',
#   'clearly',
#   'small',
#   'rubber',
#   'in',
#   'great',
#   ',',
#   ','],
#  ('a', 'holds'): ['case'],
#  ('sturdy', 'my'): ['that'],
#  ('case', 'large'): ['holds'],
#  ('that', 'collection'): ['my'],
#  ('holds', 'of'): ['large'],
#  ('my', 'cd'): ['collection', 'op5034', 'portable'],
#  ('large', "'s"): ['of'],
#  ('collection', 'and'): ['cd', 'flac', 'video'],
#  ('of', 'dvd'): ["'s"],
#  ('cd', "'s"): ['and', 'but'],
#  ("'s", '.'): ['dvd',
#   'noticeable',
#   'is',
#   'the',
#   'little',
#   'working',
#   'static',
#   'fast',
#   'than',
#   'are',
#   'to',
#   "'ve",
#   'theater',
#   'or',
#   'big',
#   'cord',
#   'good',
#   'its',
#   '80mm',
#   'small',
#   'sony',
#   'in',
#   'to',
#   'great',
#   'small',
#   'physics',
#   'good',
#   'cutie',
#   'wire',
#   'darn'],
#  ('and', 'my'): ["'s",
#   'inside',
#   'with',
#   'to',
#   'record',
#   'fit',
#   'one',
#   "'m",
#   'it',
#   'add',
#   'ranges',
#   'shipped',
#   'i',
#   'router',
#   "'m",
#   'it',
#   'fulfilled',
#   'francisco',
#   'handspring',
#   'quickly',
#   'force',
#   'ipod',
#   'it',
#   'speed',
#   'bands',
#   'one',
#   'trials'],
#  ('dvd', 'other'): ['.'],
#  ("'s", 'cases'): ['my'],
#  ('.', 'were'): ['other', 'only', 'ear', 'and'],
#  ('my', 'flimsy'): ['cases'],
#  ('other', 'and'): ['were', 'like', 'applications', 'have'],
#  ('cases', 'wore'): ['flimsy'],
#  ('were', 'out'): ['and'],
#  ('flimsy', 'fast'): ['wore'],
#  ('and', '.'): ['out',
#   'smartmedia',
#   'or',
#   'to',
#   'on',
#   'do',
#   'us',
#   'more',
#   'still',
#   'great',
#   'that',
#   'played',
#   'rj45',
#   'very',
#   'sub',
#   'video',
#   'it',
#   'good',
#   'come',
#   'sound',
#   'center',
#   'power',
#   'my',
#   'flat',
#   'great',
#   'fair',
#   'fm',
#   'something',
#   'way',
#   'apple',
#   'good',
#   'one',
#   "'s",
#   'were',
#   'optical',
#   'very',
#   'small',
#   'you',
#   'all',
#   'as',
#   'my',
#   'general',
#   'of',
#   'in',
#   'full',
#   'inches',
#   'raiders',
#   'drums',
#   'windows',
#   '.',
#   'centrino',
#   'sound',
#   'network',
#   'this',
#   'works',
#   'no',
#   'it',
#   'maybe',
#   'love',
#   'handset',
#   'small',
#   'is',
#   'lightning',
#   'the',
#   'not',
#   'of',
#   'to',
#   'to',
#   'is',
#   "'s",
#   'acustic',
#   'your',
#   'comfortable',
#   'scroll',
#   'the',
#   'it',
#   'solo',
#   'and',
#   'high',
#   'online',
#   'use',
#   'good',
#   'the',
#   'combat',
#   'it',
#   'an',
#   'through',
#   'everywhere',
#   'space',
#   'were',
#   'very',
#   'worked',
#   'button',
#   'going',
#   'them',
#   "n't",
#   'is',
#   'kreme',
#   'was',
#   'was',
#   'digital',
#   'are',
#   'the',
#   'playing',
#   'sound',
#   'sounded',
#   'on',
#   'wireless',
#   'to',
#   'the',
#   '1',
#   'so',
#   'like',
#   'usb',
#   'to',
#   'through',
#   ',',
#   'of',
#   'is',
#   'the',
#   'the',
#   'internet',
#   'few',
#   'ability',
#   'love',
#   'no',
#   'loved',
#   'love',
#   'love',
#   'to',
#   'in',
#   'love',
#   'works',
#   ';',
#   'as',
#   'headphone',
#   'very',
#   'the',
#   'this',
#   'to',
#   'copied',
#   'insulated',
#   'bit',
#   'and',
#   'customer',
#   'your',
#   'radio',
#   'very',
#   'are',
#   'right',
#   'perfect',
#   'the',
#   'is',
#   'manufactured',
#   'is',
#   'so',
#   'of',
#   'the',
#   'settings',
#   'your',
#   'clear',
#   'are',
#   "'s",
#   'it',
#   'works',
#   'to',
#   'between',
#   'few'],
#  ('wore', 'this'): ['fast'],
#  ('out', 'one'): ['.'],
#  ('fast', 'has'): ['this'],
#  ('.', 'a'): ['one',
#   'and',
#   'seemed',
#   "'s",
#   'dx',
#   'thing',
#   'also',
#   "n't",
#   '.',
#   'still',
#   'originally',
#   'marathons',
#   'worn',
#   'can',
#   'may',
#   'read',
#   'product',
#   'is',
#   'should',
#   'handset',
#   'am',
#   'interface/menu',
#   'also',
#   'you',
#   'at',
#   'do',
#   'would',
#   'you',
#   'off',
#   'it',
#   'phone',
#   'calls',
#   'base',
#   "'s",
#   'came',
#   'is',
#   'also',
#   'does',
#   '--',
#   'cable',
#   'cable',
#   '20',
#   ',',
#   'top',
#   'is',
#   'discs',
#   'clickwheel',
#   'myself',
#   ',',
#   'there',
#   'jbls',
#   'already',
#   'channels',
#   "'s",
#   'it',
#   'you',
#   'much',
#   'remote',
#   'took',
#   'do',
#   'you',
#   'not',
#   'in',
#   ',',
#   'i',
#   'camera',
#   'you',
#   'is',
#   "'ve",
#   'you',
#   'well',
#   'took',
#   'are',
#   'previously',
#   'once',
#   'drum',
#   'does',
#   'you',
#   'it',
#   'was',
#   'belkin',
#   'even',
#   'tuning',
#   'looking',
#   'really',
#   'also',
#   'would',
#   'you',
#   'could',
#   'time',
#   'these',
#   'mouse',
#   'this',
#   'you',
#   'also',
#   'would',
#   'to',
#   'just',
#   'they',
#   ',',
#   'does',
#   "'m",
#   'screen',
#   'will',
#   'i',
#   "'ve",
# ...
#   '.',
#   'also',
#   'supply',
#   'plug',
#   'button',
#   'is',
#   'stick',
#   'screen',
#   '.',
#   'log',
#   'range',
#   'for',
#   'or',
#   'feel',
#   'resulted',
#   'is',
#   '.',
#   'port',
#   'is',
#   'even',
#   'mp',
#   '.',
#   'micro',
#   'stick',
#   'bar',
#   'itself',
#   'and',
#   'locations',
#   ')'],
#  ('volume', 'little'): ['is'],
#  ('control', 'heavy'): ['a'],
#  ('is', 'unless'): ['little', 'value'],
#  ('little', 'have'): ['unless', '.'],
#  ('heavy', 'somewhere'): ['you'],
#  ('unless', 'to'): ['have', 'listen'],
#  ('you', 'clip'): ['somewhere'],
#  ('have', 'it'): ['to',
#   'seen',
#   'regretted',
#   'space',
#   '.',
#   'to',
#   'problems',
#   'available',
#   'tunebase',
#   'correct',
#   'complaints',
#   'problem',
#   'worry',
#   'instance',
#   'say',
#   'hands',
#   'complaints'],
#  ('somewhere', 'to'): ['clip', 'hate', 'hate'],
#  ('to', '('): ['it',
#   'top',
#   'very',
#   'the',
#   'keyboards',
#   'the',
#   'web',
#   ',',
#   'full',
#   'world',
#   'other',
#   'display',
#   '2.4',
#   'first',
#   'this',
#   'original'],
#  ('clip', 'this'): ['to', 'i'],
#  ('it', 'might'): ['('],
#  ('to', 'be'): ['this', '.', 'upward'],
#  ('(', 'a'): ['might',
#   'belkin',
#   'did',
#   'possibly',
#   'want',
#   '$',
#   ')',
#   'do',
#   'use',
#   'think',
#   ',',
#   'is',
#   'mannual'],
#  ('this', 'problem'): ['be', 'solved', 'not', 'not'],
#  ('might', 'for'): ['a', 'in'],
#  ('be', 'runners'): ['problem'],
#  ('a', ')'): ['for',
#   'ethernet',
#   'bmw',
#   'size',
#   'about',
#   '5.1',
#   'as',
#   ':',
#   'minutes',
#   'hour',
#   '.',
#   '.',
#   'or',
#   'one'],
#  ('this', 'so'): ['card', 'version', 'and'],
#  ('cf', 'fast'): ['is'],
#  ('card', 'that'): ['so', 'well', 'a'],
#  ('is', 'i'): ['fast',
#   'cable',
#   'so-so',
#   'good',
#   'best',
#   'short',
#   'good',
#   'good',
#   'incredible',
#   'good',
#   'io-intensive',
#   'great',
#   '4th',
#   'cool',
#   'only',
#   'good',
#   'great',
#   'handy',
#   'too',
#   'best',
#   'clear',
#   'snap',
#   'reliable',
#   'new',
#   '2nd',
#   'long',
#   'only',
#   'padded',
#   'breeze',
#   '-',
#   'price',
#   'contained',
#   'same',
#   'charged',
#   ',',
#   'bright',
#   'popular',
#   'lowest',
#   'media',
#   'enough',
#   'third',
#   'however',
#   'sublime',
#   'issue',
#   'remote',
#   '.',
#   'interesting',
#   'pain',
#   'endless',
#   'slow',
#   'best',
#   'model',
#   'low',
#   'better',
#   'freeing',
#   'written',
#   'portable',
#   'rockinest',
#   'godsend',
#   '(',
#   'you'],
#  ('so', 'can'): ['that', 'that'],
#  ('fast', 'run'): ['i'],
#  ('that', 'my'): ['can',
#   'use',
#   'fit',
#   'this',
#   'to',
#   'can',
#   'had',
#   'keep',
#   'gave'],
#  ('i', 'shutter'): ['run'],
#  ('can', 'on'): ['my', 'from', 'voice', 'a', 'and'],
#  ('run', 'my'): ['shutter'],
#  ('my', 'camera'): ['on', 'in', 's2-is', 'and'],
#  ('shutter', 'non'): ['my'],
#  ('on', 'stop'): ['camera'],
#  ('my', 'until'): ['non'],
#  ('camera', 'the'): ['stop', 'however', 'burn', 'great', 'but', 'you'],
#  ('non', 'card'): ['until'],
#  ('stop', 'is'): ['the'],
#  ('until', 'full'): ['card'],
#  ('the', 'at'): ['is',
#   'ipod',
#   'worked',
#   'tunes',
#   'are',
#   'and',
#   'must',
#   'fm',
#   'i',
#   '(',
#   'map',
#   'c5xx',
#   "'s",
#   'their',
#   'decade',
#   'i',
#   'and',
#   'controlled',
#   'on'],
#  ('card', 'a'): ['full', 'i', 'overall'],
#  ('is', 'frame'): ['at'],
#  ('full', 'rate'): ['a'],
#  ('at', 'of'): ['frame',
#   '2',
#   '480',
#   'desk',
#   'early',
#   'a',
#   'a',
#   '.',
#   'sound',
#   'opposite'],
#  ('a', '3.5'): ['rate'],
#  ('frame', 'fps'): ['of'],
#  ('rate', '.'): ['3.5', 'the', 'high'],
#  ('of', 'no'): ['fps', ','],
#  ('3.5', 'lag'): ['.'],
#  ('fps', 'or'): ['no'],
#  ('.', 'slow'): ['lag', 'v3m'],
#  ('no', 'down'): ['or'],
#  ('lag', '.'): ['slow'],
#  ('or', 'that'): ['down', 'same', 'should', 'else', 'enough', 'should'],
#  ('slow', 'is'): ['.'],
#  ('down', 'amazing'): ['that'],
#  ('.', '.'): ['is',
#   ',',
#   'the',
#   'do',
#   "'s",
#   'is',
#   "'s",
#   'truly',
#   'more',
#   'loves',
#   'be',
#   'quality',
#   'recomend',
#   'my',
#   '%',
#   'worked',
#   'very',
#   'too',
#   'as',
#   'idea',
#   'is',
#   'should',
#   'mini',
#   'truly',
#   'of',
#   'needs',
#   'noise',
#   'bluetooth',
#   ',',
#   'are',
#   'never',
#   'fell',
#   'work',
#   'return',
#   'the',
#   'worth',
#   'sound',
#   ')',
#   ')',
#   ')',
#   'sturdy',
#   'good',
#   'manages',
#   ')'],
#  ('that', 'it'): ['amazing',
#   'paid',
#   'keep',
#   'each',
#   'had',
#   'can',
#   ',',
#   'so',
#   'one',
#   "'d",
#   'how',
#   'got',
#   "'ve",
#   'a',
#   'i',
#   'more',
#   ',',
#   ',',
#   'and',
#   'one',
#   'you'],
#  ('is', 'makes'): ['.', ','],
#  ('amazing', 'my'): ['it'],
#  ('.', 'camera'): ['makes', 'used', 'own', 'using'],
#  ('it', 'perform'): ['my'],
#  ('makes', 'better'): ['camera'],
#  ('camera', '('): ['better'],
#  ('perform', 'canon'): ['.'],
#  ('better', 'rebel'): ['('],
#  ('.', 'xt'): ['canon'],
#  ('fast', 'well'): ['reliable', 'accurate', 'it'],
#  ('and', 'worth'): ['..'],
#  ('reliable', 'the'): ['well'],
#  ('..', 'mone'): ['worth'],
#  ('perhaps', 'to'): ['ultimate', 'just'],
#  ('ultimate', 'good'): ['to'],
#  ('addition', 'camera'): ['a'],
#  ('good', 'used'): ['.'],
#  ('camera', 'my'): ['i'],
#  ('used', 'a'): ['camera',
#   'charger',
#   'backing',
#   'i',
#   'finding',
#   'for',
#   'card',
#   'keyboard/mouse',
#   'gps',
#   'for'],
#  ('my', 'sandisk'): ['with'],
#  ('camera', 'pro'): ['a'],
#  ('with', 'duo'): ['sandisk'],
#  ('a', '('): ['pro',
#   'of',
#   'new',
#   'speaker',
#   'called',
#   'technical',
#   'file',
#   "''"],
#  ('sandisk', 'the'): ['duo', 'ti', 'ti'],
#  ('pro', 'blue'): ['('],
#  ('duo', 'one'): ['the'],
#  ('(', '...'): ['blue'],
#  ('the', ')'): ['one',
#   'and',
#   '(',
#   '(',
#   '(',
#   '.',
#   'default',
#   ',',
#   'with',
#   'bass-feel/effect',
#   'dvd',
#   'for',
#   'multifunction',
#   'installed',
#   'lemon',
#   'distance',
#   '(',
#   '(',
#   '(',
#   'one',
#   'web',
#   "'s",
#   '..',
#   'tube/glass',
#   '(',
#   ';',
#   'killer',
#   'lemon',
#   'river',
#   'i',
#   '&',
#   'generic'],
#  ('blue', 'and'): ['...'],
#  ('one', 'while'): [')'],
#  ('...', 'most'): ['and'],
#  (')', 'times'): ['while'],
#  ('and', 'it'): ['most',
#   'now',
#   'lines',
#   "n't",
#   "'ve",
#   'it',
#   'looks',
#   'he',
#   'should',
#   'kids',
#   'could',
#   ',',
#   'absolutely',
#   'is',
#   'good',
#   'most',
#   'was',
#   'sucessfully',
#   'hardly',
#   'range',
#   'would',
#   'to',
#   'analysis',
#   'internet',
#   'may',
#   ',',
#   'listened',
#   'edges',
#   'look',
#   "n't",
#   'reason',
#   'leg',
#   'has',
#   'data',
#   'price',
#   'do',
#   'just',
#   'battery',
#   "'d",
#   'must',
#   'also',
#   'can',
#   'fact',
#   'nano',
#   'generally',
#   'it',
#   'problems',
#   'how',
#   'a',
#   'does',
#   'only',
#   ',',
#   "'ll",
#   'me',
#   'exactly'],
#  ('while', 'was'): ['times'],
#  ('most', 'fine'): ['it'],
#  ('times', ','): ['was', 'a'],
#  ('it', 'when'): ['fine',
#   'sufficient',
#   "n't",
#   'ocasionally',
#   'beautifully',
#   "n't",
#   'up'],
#  ('was', 'i'): [',',
#   'the',
#   'recommended',
#   'valid',
#   're-order',
#   'surprised',
#   'thick',
#   'main',
#   '200',
#   '.',
#   'surprised',
#   ',',
#   'week',
#   'surprised',
#   'joke',
#   'last',
#   'simple',
#   '.',
#   'successfully',
#   'the',
#   'much',
#   'normal',
#   'removed',
#   'heaven',
#   'consideration',
#   'object',
#   'enough',
#   'first',
#   ')'],
#  ('fine', 'needed'): ['when'],
#  ('when', 'take'): ['needed'],
#  ('i', 'pictures'): ['to', 'about', 'tons', 'from'],
#  ('needed', 'in'): ['take', 'now', 'use'],
#  ('to', 'quick'): ['pictures'],
#  ('take', 'succession'): ['in'],
#  ('pictures', '-'): ['quick'],
#  ('quick', 'let'): ['-'],
#  ('succession', 'me'): ['it'],
#  ('-', 'down'): ['let'],
#  ('let', 'the'): ['down', 'fingers'],
#  ('me', 'ultra'): ['.'],
#  ('down', 'ii'): ['the'],
#  ('the', 'noticably'): ['ii'],
#  ('ultra', 'faster'): ['is'],
#  ('ii', '.'): ['noticably', 'the'],
#  ('is', 'you'): ['faster',
#   'destroyed',
#   'true',
#   'make',
#   ',',
#   'enough',
#   'object',
#   'good',
#   'range',
#   '.',
#   'number',
#   'best',
#   'nightmare',
#   ',',
#   'easier',
#   'out',
#   ',',
#   '.',
#   'camera',
#   'good',
#   ',',
#   'product',
#   'easy',
#   'best'],
#  ('noticably', 'will'): ['.'],
#  ('faster', 'not'): ['you'],
#  ('.', 'regret'): ['will'],
#  ('you', 'buying'): ['not'],
#  ('will', 'this'): ['regret', 'to', 'fine'],
#  ('the', 'secure'): ['512', 'much'],
#  ('sandisk', 'digitial'): ['mb'],
#  ('512', 'ultra'): ['secure'],
#  ('mb', 'ii'): ['digitial'],
#  ('secure', '('): ['ultra'],
#  ('digitial', 'sdsdh-512-901'): ['ii'],
#  ('ultra', ')'): ['('],
#  ('ii', 'sent'): ['sdsdh-512-901'],
#  ('(', 'to'): [')', 'both', 'has', ')', 'base', 'means', 'i'],
#  ('sdsdh-512-901', 'me'): ['sent'],
#  (')', 'was'): ['to', 'so', 'decided', ',', 'the', 'set', '--'],
#  ('sent', 'not'): ['me'],
#  ('to', 'the'): ['was',
#   'with',
#   'outside',
#   'top',
#   'data',
#   'sure',
#   'photos',
#   'true',
#   'or',
#   'firmware',
#   'about',
#   'about',
#   ':',
#   '.',
#   'playlists',
#   'one',
#   'touches',
#   '(',
#   'fair',
#   'up',
#   'music',
#   'out',
#   '.',
#   'on',
#   'picture',
#   'television',
#   'and',
#   'and',
#   'inches',
#   'viewer',
#   'yes',
#   'nearly',
#   'how',
#   'tv',
#   'because',
#   'camera',
#   'and',
#   'paper',
#   'from',
#   'in',
#   'used',
#   'switching',
#   'beat',
#   'accidentally',
#   'out',
#   'is',
#   'one',
#   'it',
#   'point',
#   'used',
#   'music',
#   'over',
#   'dock',
#   'to',
#   'factors',
#   ',',
#   'format',
#   'cd',
#   '.',
#   'cured',
#   'them',
#   'music',
#   'is',
#   'it',
#   'ipod',
#   'bottom',
#   'payment',
#   'out',
#   'up',
#   '.',
#   'placed',
#   'comment',
#   'songs',
#   'out',
#   'prepared',
#   'back',
#   'in',
#   'it',
#   '.',
#   'this',
#   'plug',
#   'sure',
#   'friends',
#   'behavior',
#   'back',
#   'them',
#   'with',
#   'them',
#   'claims',
#   'one',
#   'it',
#   'over',
#   'grave',
#   'is',
#   'connected',
#   ',',
#   'track',
#   'static',
#   ',',
#   'av',
#   'side',
#   'double-seam',
#   'one',
#   ',',
#   'software',
#   'to',
#   'minutes',
#   'bed-and-breakfast',
#   'vehicle',
#   'it',
#   '.',
#   'close',
#   'around',
#   'it',
#   'it'],
#  ('me', 'item'): ['not'],
#  ('not', 'ordered'): ['item'],
#  ('the', '.'): ['i',
#   'line',
#   'was',
#   'anytime',
#   'worked',
#   'mounting',
#   'vhs',
#   'low',
#   'of',
#   'works',
#   'are',
#   'was',
#   '.',
#   'software',
#   'works',
#   'common',
#   'one',
#   'to',
#   'really',
#   'for',
#   'are',
#   'office',
#   'machine',
#   'trash',
#   'panasonic',
#   'are',
#   'quality',
#   'is',
#   'fool',
#   'display',
#   'price',
#   'is',
#   'cable',
#   'lyra',
#   "''",
#   ',',
#   'of',
#   'mini',
#   'with',
#   'form',
#   'to',
#   '1-2-3',
#   'much',
#   'center',
#   'for',
#   'dead',
#   'fm',
#   'is',
#   'others',
#   'for',
#   'now',
#   'is',
#   'fully',
#   'line-in',
#   'of',
#   'profit',
#   'included',
#   'is',
#   'is',
#   'works',
#   'device',
#   'color',
#   'gen',
#   'right',
#   'of',
#   'webcams',
#   'pro',
#   'version',
#   'zen',
#   'for',
#   'loved',
#   'optic',
#   'couple',
#   '.',
#   'itself',
#   'is',
#   'noise-cancelling',
#   'and',
#   'is',
#   'or',
#   'before',
#   'factor',
#   "'s",
#   'are',
#   'and',
#   'have',
#   'each',
#   'off',
#   'of',
#   'self-explanatory',
#   'after',
#   'life',
#   'cables',
#   'sized',
#   'display',
#   'to',
#   '5',
#   ',',
#   'sleep',
#   'for',
#   'is',
#   'is',
#   'is',
#   'is',
#   'battery',
#   'and',
#   'is',
#   '4',
#   'are',
#   'was',
#   'of',
#   '4gb',
#   'bits',
#   ',',
#   'motorola',
#   'and',
#   'things',
#   'respond',
#   'positive',
#   'is',
#   'turns',
#   'and',
#   'then',
#   'way',
#   'few',
#   'great',
#   'is',
#   'you',
#   'space',
#   'sansa',
#   'feature',
#   "''",
#   'is',
#   'from',
#   'line',
#   'and',
#   '2.1',
#   'were',
#   'video',
#   'bothers',
#   ',',
#   'update',
#   'united',
#   'en-7100',
#   'to',
#   'players',
#   'are',
#   'series',
#   'in',
#   'comes',
#   'call',
#   'i',
#   'audio-video',
#   'clog',
#   'for',
#   'of',
#   'signal',
#   'sansa',
#   'dvd',
#   'possible',
#   'anodized',
#   'tunedok',
#   '1',
#   'having',
#   "'s",
#   'price',
#   'formats',
#   'has',
#   'outside',
#   'for',
#   'shows',
#   'they',
#   'urc9910',
#   'q5949x',
#   'very',
#   'to',
#   'wind',
#   'is',
#   'important',
#   'at',
#   'and',
#   'first',
#   'safety',
#   'and',
#   'wi-fi',
#   'channels',
#   'mentioned',
#   'are',
#   'same',
#   'and',
#   'plastic',
#   'gb',
#   'hold',
#   'is',
#   'came',
#   'came',
#   'is',
#   'signal',
#   'is',
#   'for',
#   'is',
#   'choice',
#   '50',
#   'works',
#   'so',
#   'of',
#   'were',
#   'is',
#   'is',
#   'very',
#   'for',
#   'ctrex',
#   'things',
#   'charging',
#   'for',
#   'is',
#   'a210',
#   'for',
#   'carted',
#   'company',
#   'is',
#   'come',
#   'sync',
#   'maps',
#   'is',
#   'ran',
#   '3',
#   "'s",
#   '5',
#   'are',
#   '7050',
#   ',',
#   'worked',
#   'buttons',
#   'printing',
#   'shaped',
#   'was',
#   'pro',
#   'on'],
#  ('item', 'i'): ['ordered'],
#  ('i', 'returned'): ['.', 'bought'],
#  ('ordered', 'the'): ['i', 'started'],
#  ('.', 'item'): ['returned', 'if', 'bought', 'if'],
#  ('returned', 'unopened'): ['item'],
#  ('definitely', 'card'): ['this'],
#  ('recommend', ','): ['memory', '?', 'it'],
#  ('this', 'download'): ['card'],
#  ('memory', 'time'): [','],
#  ('card', 'is'): ['download', 'the'],
#  (',', 'great'): ['time',
#   '.',
#   'music',
#   'make',
#   'is',
#   'to-dos',
#   'they',
#   'are',
#   'is',
#   'amazon',
#   "'s",
#   'is',
#   'quality',
#   ',',
#   'thing',
#   'is',
#   "'s",
#   'is',
#   'is',
#   "'s",
#   'it',
#   'this',
#   "'s",
#   'is',
#   "'s",
#   'up',
#   'product',
#   'beautifully',
#   'was',
#   'was'],
#  ('download', '.'): ['is', 'my'],
#  ('time', '.'): ['great',
#   'sturdily',
#   'to',
#   'parked',
#   'unbending',
#   'and',
#   'no'],
#  ('i', 'have'): ['happy',
#   'say',
#   'going',
#   'like',
#   'i',
#   'that',
#   'going',
#   'did',
#   '.',
#   'this',
#   "n't",
#   "n't",
#   'not',
#   'like'],
#  ('am', 'several'): ['to'],
#  ('happy', 'sandisk'): ['have'],
#  ('to', 'products'): ['several', 'brand'],
#  ('have', ','): ['sandisk',
#   'qam',
#   'sensitivity',
#   'ny',
#   'dark',
#   'station',
#   'richest',
#   'to',
#   'u3',
#   'quest',
#   'range',
#   'shuffle',
#   'zillion',
#   '.',
#   'helicopter',
#   'gateway',
#   'directv',
#   'ear',
#   'my',
#   'hearing',
#   'bass',
#   'bass',
#   ')',
#   'smaller',
#   'every',
#   'this',
#   'little'],
#  ('several', 'and'): ['products', 'these', 'now', 'trips'],
#  ('sandisk', 'all'): [','],
#  ('products', 'of'): ['and'],
#  (',', 'them'): ['all',
#   'both',
#   'none',
#   'best',
#   'i',
#   'impression',
#   'immediately',
#   'determined',
#   'and',
#   'just',
#   'really',
#   'pleased',
#   'really',
#   'feel',
#   'determined'],
#  ('and', 'are'): ['of',
#   'what',
#   'so',
#   ',',
#   'the',
#   'surge',
#   'speaker',
#   'if',
#   'that',
#   'again',
#   'plasma',
#   'dvd',
#   'the',
#   'which',
#   'bass',
#   'bose',
#   'more',
#   ',',
#   'other',
#   'mask',
#   'although',
#   ','],
#  ('all', 'excellent'): ['them', 'is'],
#  ('of', '.'): ['are',
#   'this',
#   'great',
#   'when',
#   'wireless',
#   "'s",
#   'and',
#   'noisy',
#   'pen',
#   'windows/dos',
#   'work',
#   'the',
#   'and',
#   'cable',
#   'brother',
#   'years',
#   ',',
#   'ends',
#   'touchpad',
#   'my',
#   'on',
#   'previous',
#   ',',
#   "'toys",
#   'used',
#   'rough',
#   'cancelling',
#   'when',
#   'noise',
#   'to',
#   'many',
#   'mp3',
#   'speakers',
#   '&',
#   'is',
#   'the',
#   'the',
#   'streets',
#   'mouse',
#   'headphones',
#   'sweet',
#   'no',
#   'dead',
#   'movie',
#   'for',
#   'purchase',
#   'manual',
#   'playback',
#   'street',
#   'pricey',
#   'movie',
#   'miniplug',
#   'on',
#   'tight',
#   'collection',
#   'satelite/dvr',
#   'external',
#   'same',
#   'amazing',
#   'is',
#   'cable',
#   'material',
#   'poor',
#   'stereo',
#   'reviews',
#   'these',
#   'quality',
#   'i',
#   'no',
#   'planes',
#   ',',
#   'steering',
#   'favorite',
#   'network',
#   'same',
#   'and',
#   'intercom',
#   'rainbow',
#   'tv',
#   'are',
#   'cheap',
#   'so',
#   'video',
#   'music',
#   'other',
#   'possible'],
#  ('the', 'absoultely'): ['sdsdh-1024-901'],
#  ('sandisk', 'worth'): ['is'],
#  ('sdsdh-1024-901', 'the'): ['absoultely'],
#  ('is', 'extra'): ['worth'],
#  ('absoultely', 'money'): ['the'],
#  ('worth', 'if'): ['extra', 'money', 'extra', 'money'],
#  ('the', 'you'): ['money',
#   'also',
#   'disk',
#   '.',
#   'for',
#   'and',
#   'i',
#   ',',
#   'radio',
#   'turns',
#   'stronger',
#   ',',
#   '.',
#   '.',
#   'presets',
#   "''",
#   '.',
#   'brand',
#   '6000.',
#   'software',
#   'the',
#   'are',
#   'right',
#   'that',
#   'channel',
#   '``',
#   'nano',
#   ':',
#   'crisp',
#   '.',
#   'stores',
#   'also',
#   ',',
#   '.',
#   '.',
#   '.',
#   'that',
#   'dictates',
#   '.',
#   ',',
#   'options',
#   '.',
#   'buttons',
#   '.',
#   'adapter',
#   '.',
#   'port',
#   'prompts',
#   '.',
#   'is',
#   '.',
#   'parts',
#   'book',
#   'from',
#   'so',
#   'sound',
#   '.',
#   'but',
#   ',',
#   '.',
#   'chance',
#   ',',
#   'band',
#   ',',
#   'picture',
#   'is',
#   'player',
#   '.',
#   'that',
#   'eye'],
#  ('extra', 'love'): ['if', '!'],
#  ('money', 'to'): ['you'],
#  ('if', 'take'): ['love', 'want'],
#  ('you', 'many'): ['to', 'add'],
#  ('love', 'pictures'): ['take'],
#  ('to', 'without'): ['many'],
#  ('take', 'worrying'): ['pictures'],
#  ...}

# %%
# 將中間字矩陣變成或然率向量
fivegram_probabilities = {}
for k, words in iteritems(fivegrams):
    # 產生一個  word -> count 字典
    if len(set(words)) > 1:
        # 如果中間字middle word不只有一個機率 
        d = {}
        n = 0
        for w in words:
            if w not in d:
                d[w] = 0
            d[w] += 1
            n += 1
        for w, c in iteritems(d):
            d[w] = float(c) / n
        fivegram_probabilities[k] = d

# %%
def random_sample(d):
    # 從字典隨機選出一個帶機率值的樣本，回傳累積機率值最大的字
    r = random.random()
    cumulative = 0
    for w, p in iteritems(d):
        cumulative += p
        if r < cumulative:
            return w

# %%
def test_spinner():
    review = random.choice(positive_reviews)
    s = review.text.lower()
    print("Original:", s)
    tokens = nltk.tokenize.word_tokenize(s)
    for i in range(len(tokens) - 4):
        if random.random() < 0.2: # 20% chance of replacement
            k = (tokens[i], tokens[i+4])
            if k in fivegram_probabilities:
                w = random_sample(fivegram_probabilities[k])
                tokens[i+2] = w
    print("Spun:")
    print(" ".join(tokens).replace(" .", ".").replace(" '", "'").replace(" ,", ",").replace("$ ", "$").replace(" !", "!"))

# %%
if __name__ == '__main__':
    test_spinner()
# Out:
# Original:
# this is my first hotas, but i did a good bit of research.  it is very easy to set up, and the sst programming is very helpful setting the shift key.  the joystick is easy to move, which is nice in a close dogfight.  i am very glad that i bought this hotas, because i have had no problems with it.  i highly recommend this system to anyone
#
# Spun:
# this is my first hotas, but's did a good bit of research. it is very first to set it, and the sst programming is very helpful setting the a key. the joystick is easy bit move, which one me in a close dogfight. i am very glad that i bought it hotas, because i have had these problems with it. i summary recommend this system to anyone
